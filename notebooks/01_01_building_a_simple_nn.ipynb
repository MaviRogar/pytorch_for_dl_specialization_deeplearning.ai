# %% [markdown]
# <a href="https://colab.research.google.com/github/MaviRogar/pytorch_for_dl_specialization_deeplearning.ai/blob/main/notebooks/01_01_building_a_simple_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
